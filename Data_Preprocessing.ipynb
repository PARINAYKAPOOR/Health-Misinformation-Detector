# %%
import pandas as pd
from IPython.display import display


fake_information = pd.read_csv("CoAID-master/05-01-2020/NewsFakeCOVID-19.csv") 
real_information = pd.read_csv("CoAID-master/05-01-2020/NewsRealCOVID-19.csv")


print("Fake news shape:", fake_information.shape)
print("Real news shape:", real_information.shape)


fake_clean = fake_information[['title', 'content', 'fact_check_url', 'news_url']].copy()
real_clean = real_information[['title', 'content', 'fact_check_url', 'news_url']].copy()


fake_clean['label'] = 0  # Negative outcome 
real_clean['label'] = 1  # Positive outcome 

combined_information = pd.concat([fake_clean, real_clean], ignore_index=True)

combined_information.dropna(subset=['title', 'content'], inplace=True)

combined_information.reset_index(drop=True, inplace=True)


print("\nCombined Dataset Preview:")
# print(combined_information.head(1))
display(combined_information.head(1500))
# Out:
# Fake news shape: (572, 15)
# Real news shape: (1590, 10)
#
# Combined Dataset Preview:
#                                                   title  \
# 0     Wisconsin is Òclearly seeing a decline in COVI...
# 1     Says WisconsinÕs in-person election has caused...
# 2     Nobel laureate Luc Montagnier claimed that the...
# 3     A video argues that the pandemic could have re...
# 4     Gov. Andrew Cuomo Òwas simply saying if we can...
# ...                                                 ...
# 1495    "#ThanksHealthHeros - World Health Day Message"
# 1496  "New WHO recommendations to prevent tuberculos...
# 1497  "Meeting Postponement: Preparing Together: Kee...
# 1498  "Statement on the 5th meeting of the Internati...
# 1499  "WHO Director-General’s Statement on IHR Emerg...
#
#                                                 content  \
# 0     speaker robin vos r rochester and senate major...
# 1          this is not the page you 're looking for ..
# 2     contrary to the narrative that is being pushed...
# 3     programming alert exclusive documentary on ori...
# 4     buffalo n.y. wivb)--mayor byron brown was hand...
# ...                                                 ...
# 1495  today is world health day. this day is especia...
# 1496  geneva new world health organization who guida...
# 1497  a high level meeting on diplomacy for health s...
# 1498  the 5th meeting of the emergency committee con...
# 1499  the international health regulations emergency...
#
#                                          fact_check_url  \
# 0     https://www.politifact.com/factchecks/2020/apr...
# 1     https://www.politifact.com/factchecks/2020/apr...
# 2     https://healthfeedback.org/claimreview/claim-b...
# 3     https://healthfeedback.org/viral-video-promote...
# 4     https://www.politifact.com/factchecks/2020/apr...
# ...                                                 ...
# 1495                                            who.int
# 1496                                            who.int
# 1497                                            who.int
# 1498                                            who.int
# 1499                                            who.int
#
#                                                news_url  label
# 0     http://legis.wisconsin.gov/assembly/republican...      0
# 1     https://secondnexus.com/wisconsin-gop-new-case...      0
# 2     https://www.gilmorehealth.com/chinese-coronavi...      0
# 3     https://www.theepochtimes.com/programming-aler...      0
# 4     https://www.wivb.com/news/watch-interview-with...      0
# ...                                                 ...    ...
# 1495  https://www.who.int/news-room/detail/07-04-202...      1
# 1496  https://www.who.int/news-room/detail/24-03-202...      1
# 1497  https://www.who.int/news-room/events/detail/20...      1
# 1498  https://www.who.int/news-room/detail/14-04-202...      1
# 1499  https://www.who.int/news-room/detail/14-04-202...      1
#
# [1500 rows x 5 columns]

# %%
combined_information.to_csv("combined_health_misinformation.csv", index=False)
